# %%
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

''' 
This program merges all of the separate programs (protagonists.ipynb and synopsis.ipynb) and adds the text search function. It will return all of the movies
that contain family keywords inside a data frame. This program runs in approximately 7-8 mins."
'''

def movie_table(url):
    webpage = url
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')
    beautiful_page = soup.get_text()

    ratings = []
    years = []
    titles = []
    movie_nums = []

    lines = beautiful_page.splitlines()

    for line in lines:
        if "(20" in line and ")" in line or '(19' in line and ')' in line:
            years.append(line)

    rep_years = []
    nrep_years = []
    year_indices = []

    for year in years:
        
        if lines.count(year) > 1:
            if year not in rep_years:
                rep_years.append(year)
        if lines.count(year) == 1:
            nrep_years.append(year)

    for i in range(len(rep_years)):
        first_instance = lines.index(rep_years[i])
        year_indices.append(first_instance)

        for j, item in enumerate(lines[first_instance+1:], start=first_instance+1):
            if item == rep_years[i]:
                year_indices.append(j)

    for year in nrep_years:
        if year in lines:
            index = lines.index(year)
            year_indices.append(index)


    for index in sorted(year_indices):
        title = lines[index-1]
        titles.append(title)

        rating = lines[index+6]
        ratings.append(rating)

        movie_num = lines[index-3]
        movie_nums.append(movie_num) 
        

    ratings = [rating.lstrip() for rating in ratings]
    for i in range(len(ratings)):
        if ratings[i] == '':
            ratings[i] = "None"


    for i in range(len(years)):
        for j in range(len(years[i])):
            if years[i][j].isnumeric():
                number_index = years[i].find(years[i][j])
                years[i] = years[i][number_index:number_index+4]
                break


    table_data = list(zip(movie_nums, titles, years, ratings))
    # headers = ["Movie Number", "Title", "Year", "Rating"]

    # print(tabulate(table_data, headers=headers))
    
    return table_data

synopsis_list = []

# Function to get the synopsis from every movie in the webpage
def synopses(link):
    webpage = link
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')

    url_list = []
    movie_url_list = []
    movie_ref_nums = []

    # Get all the hyperlinks
    for link in soup.find_all('a'):
        url_list.append(link.get('href'))

    # Filter to get movie title hyperlinks
    for url in url_list:
        if '/title/tt' in url:
            if url not in movie_url_list:
                movie_url_list.append(url) 

    # Take the reference number from the movie url
    for movie_url in movie_url_list:
        movie_ref_nums.append(movie_url[7:16])


    # Extract the synopsis from every movie then append to a list
    driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')

    for i in movie_ref_nums:
        url = "https://www.imdb.com/title/" + i + "/plotsummary/?ref_=tt_stry_pl#synopsis"
        try:
            driver.get(url)
            synopsis_element = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[2]/div[2]/ul/li/div/div/div/div/div')
        except:
            synopsis_list.append("No Synopsis")
        else:
            synopsis = synopsis_element.text
            synopsis_list.append(synopsis)

# Function that find family related words on the synopsis
def text_search(synopsis_list):
    # The indices of the synopses that contain any of the keywords
    match_index_list = []

    keywords = ["family", "parenting", "father", "mother", "son", "daughter", "sibling", "brother", "sister", "marriage", "divorce", "blended family", "adoption",
                "foster care", "custody", "inheritance", "legacy", "generations", "multigenerational", "family reunion", "family secrets", "family drama", "dysfunctional", 
                "dysfunctional family", "family conflict", "family relationships", "family values", "family ties", "parent-child relationship", "relationship",
                "coming-of-age", "parenthood", "growing up", "childhood", "teenage years", "aging parents", "grandparents"]

    for i in range(len(synopsis_list)):
        for keyword in keywords:
            if keyword in synopsis_list[i]:
                if i not in match_index_list:
                    match_index_list.append(i)

    return match_index_list

# Call synopses function to put all synopses into list
synopses("https://www.imdb.com/search/title/?title_type=feature&genres=animation&view=simple&ref_=adv_prv")
synopses("https://www.imdb.com/search/title/?title_type=feature&genres=animation&view=simple&start=51&ref_=adv_nxt")

# Create Data Frame for Movie information
df_animation_1 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&genres=animation&view=simple&ref_=adv_prv"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_animation_2 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&genres=animation&view=simple&start=51&ref_=adv_nxt"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_animation = pd.concat([df_animation_1, df_animation_2], ignore_index=True).assign(Genre='Animation', Synopsis=synopsis_list)

# Output information of movies that contain family keywords
pd.set_option('display.max_rows', None)
df_animation.iloc[text_search(synopsis_list)]
# Out:
#    Index                              Title  Year Rating      Genre  \
# 4     5.                     Over the Hedge  2006    6.7  Animation
# 6     7.  Spider-Man: Into the Spider-Verse  2018    8.4  Animation
# 8     9.                              Moana  2016    7.6  Animation
# 10   11.     Guillermo del Toro's Pinocchio  2022    7.6  Animation
# 11   12.                         Shark Tale  2004      6  Animation
# 13   14.                             Sing 2  2021    7.4  Animation
# 15   16.                            Encanto  2021    7.2  Animation
# 16   17.                The Prince of Egypt  1998    7.2  Animation
# 17   18.                      The Lion King  2019    6.8  Animation
# 18   19.                      Spirited Away  2001    8.6  Animation
# 19   20.                      The Lion King  1994    8.5  Animation
# 20   21.                         Your Name.  2016    8.4  Animation
# 21   22.           Minions: The Rise of Gru  2022    6.5  Animation
# 22   23.                               Cars  2006    7.2  Animation
# 23   24.                               Home  2015    6.6  Animation
# 24   25.                       The Bad Guys  2022    6.8  Animation
# 25   26.                              Shrek  2001    7.9  Animation
# 26   27.                           Zootopia  2016      8  Animation
# 27   28.                        Ratatouille  2007    8.1  Animation
# 29   30.               Howl's Moving Castle  2004    8.2  Animation
# 30   31.                 Hotel Transylvania  2012      7  Animation
# 31   32.                         Inside Out  2015    8.1  Animation
# 32   33.                      Puss in Boots  2011    6.6  Animation
# 34   35.                          Toy Story  1995    8.3  Animation
# 35   36.                        Turning Red  2022      7  Animation
# 37   38.                               Coco  2017    8.4  Animation
# 39   40.                               Sing  2016    7.1  Animation
# 40   41.                            Tangled  2010    7.7  Animation
# 41   42.                  Fantastic Mr. Fox  2009    7.9  Animation
# 43   44.                       Finding Nemo  2003    8.2  Animation
# 44   45.                             Frozen  2013    7.4  Animation
# 45   46.                           Coraline  2009    7.7  Animation
# 47   48.                           Hercules  1997    7.3  Animation
# 48   49.                                Hop  2011    5.4  Animation
# 49   50.                             WALL·E  2008    8.4  Animation
# 50   51.                                Rio  2011    6.9  Animation
# 51   52.                                 Up  2009    8.3  Animation
# 52   53.           How to Train Your Dragon  2010    8.1  Animation
# 53   54.                     Monsters, Inc.  2001    8.1  Animation
# 54   55.                     The Lego Movie  2014    7.7  Animation
# 55   56.                 The Little Mermaid  1989    7.6  Animation
# 56   57.                             Trolls  2016    6.4  Animation
# 58   59.                      Kung Fu Panda  2008    7.6  Animation
# 59   60.                            Shrek 2  2004    7.3  Animation
# 62   63.                       A Bug's Life  1998    7.2  Animation
# 63   64.                              Rango  2011    7.2  Animation
# 64   65.                            Aladdin  1992      8  Animation
# 66   67.                       Isle of Dogs  2018    7.8  Animation
# 67   68.                            Ice Age  2002    7.5  Animation
# 68   69.             Grave of the Fireflies  1988    8.5  Animation
# 69   70.                  The Good Dinosaur  2015    6.7  Animation
# 70   71.                               Soul  2020      8  Animation
# 72   73.                      Lilo & Stitch  2002    7.3  Animation
# 73   74.                  Trolls World Tour  2020    6.1  Animation
# 74   75.          The Princess and the Frog  2009    7.1  Animation
# 75   76.               Beauty and the Beast  1991      8  Animation
# 76   77.                  Princess Mononoke  1997    8.3  Animation
# 77   78.            Who Framed Roger Rabbit  1988    7.7  Animation
# 78   79.                      Incredibles 2  2018    7.6  Animation
# 79   80.                             Robots  2005    6.4  Animation
# 81   82.                      Despicable Me  2010    7.6  Animation
# 82   83.                              Mulan  1998    7.6  Animation
# 83   84.                        Toy Story 4  2019    7.7  Animation
# 84   85.                        Toy Story 3  2010    8.3  Animation
# 85   86.                          Frozen II  2019    6.8  Animation
# 86   87.                     Wreck-It Ralph  2012    7.7  Animation
# 88   89.           Raya and the Last Dragon  2021    7.3  Animation
# 93   94.                          Anastasia  1997    7.1  Animation
# 96   97.          Atlantis: The Lost Empire  2001    6.9  Animation
# 98   99.                              Brave  2012    7.1  Animation
#
#                                              Synopsis
# 4   Spring has arrived and an array of creatures s...
# 6   This animated film starts with Peter Parker (v...
# 8   Using a tapa cloth to animate her story, Gramm...
# 10  In Italy during the the Great War, the carpent...
# 11  Oscar (Will Smith-voice) is a little fish work...
# 13  Some time after the events of the first film, ...
# 15  While escaping her home from armed conflict, a...
# 16  In Ancient Egypt, Hebrew slaves are hard at wo...
# 17  The sun rises over the Pride Lands. Animals fr...
# 18  Ten-year-old Chihiro (voice: Daveigh Chase in ...
# 19  The Lion King takes place in the Pride Lands o...
# 20  &#12302;&#21531;&#12398;&#21517;&#12399;&#1229...
# 21  The year 1976 is where the story begins. Belle...
# 22  The movie begins with two announcers, Bob Cutl...
# 23  The alien race known as the Boov are very good...
# 24  In Los Angeles, California, in a world of huma...
# 25  A Scottish man (voiced by Mike Myers) reads a ...
# 26  In the town of Bunnyburrow, 9 year old bunny, ...
# 27  The movie opens with a TV documentary featurin...
# 29  Over a quaint area of land, shrouded by fog, a...
# 30  Dracula (voiced by Adam Sandler) is the owner ...
# 31  Riley is a girl born in Minnesota. Five emotio...
# 32  Sometime before Puss (Antonio Banderas) meets ...
# 34  A boy called Andy Davis (voice: John Morris) u...
# 35  In 2002, Meilin "Mei" Lee is a 13-year-old Chi...
# 37  In Santa Cecilia, Mexico, Imelda Rivera was th...
# 39  Set in an animated world controlled by animals...
# 40  The film opens on a Wanted poster for Flynn Ri...
# 41  "Boggis and Bunce and Bean One short, one fat,...
# 43  Two clownfish, Marlin (Albert Brooks) and his ...
# 44  The Walt Disney Pictures logo and the movie ti...
# 45  As the credits appear, a pair of metallic hand...
# 47  Based on both the legend of Hercules and Herac...
# 48  He was destined to be the Easter Bunny, but al...
# 49  A Dystopia in the Future\n\nApproximately seve...
# 50  In Rio de Janeiro, Brazil, birds sing and danc...
# 51  Young Carl Fredricksen (Jeremy Leary), a quiet...
# 52  A Viking boy called Hiccup (voice: Jay Baruche...
# 53  The city of Monstropolis in a world entirely p...
# 54  The wizard Vitruvius attempts to protect the "...
# 55  Ariel, a sixteen-year-old mermaid princess, is...
# 56  Once upon a time, the Trolls all lived in a tr...
# 58  "Legend tells of a legendary warrior whose kun...
# 59  When Shrek and Fiona come back from their hone...
# 62  On a small island with a large tree, a colony ...
# 63  In the back of a small car, in a small aquariu...
# 64  A street peddler (Robin Williams) is guiding t...
# 66  Prologue: The Boy Samurai and The Headless Anc...
# 67  20,000 years ago, a grumpy mammoth named Manfr...
# 68  &#12302;&#28779;&#22402;&#12427;&#12398;&#2267...
# 69  65 million years ago, an asteroid made its way...
# 70  Joe Gardner, a middle school music teacher, fe...
# 72  Somewhere on a distant planet, a court is call...
# 73  The film opens on a celebration of the Techno ...
# 74  In New Orleans, a young girl named Tiana ( Eli...
# 75  In the prologue, told through stained glass wi...
# 76  The tale of Princess Mononoke is a fantasy adv...
# 77  Former toon Private Eye Eddie Valiant (Bob Hos...
# 78  Agent Rick Dicker (Jonathan Banks) is intervie...
# 79  In a world of robots, the Copperbottom family ...
# 81  The film begins with the news revealing that a...
# 82  During the Han Dynasty in ancient China, the l...
# 83  Nine years ago, between the events of the seco...
# 84  Andy Davis (voice: John Morris) is 17 years ol...
# 85  The film opens with young Anna (voice of Hadle...
# 86  Wreck-It Ralph (voice of John C. Reilly) longs...
# 88  500 years prior, Kumandra was a prosperous lan...
# 93  In St Petersburg, Russia, in 1916, a lavish ba...
# 96  Milo James Thatch is a bright young man, who i...
# 98  In a prologue, we see Lord Fergus and Lady Eli...
